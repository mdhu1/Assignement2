# %%
#Question1 ) Write a Python program to remove duplicates from a list

# %%
list=[2,4,3,2,5,6,7,8,7,4,3]
print(Remove(list))
# Out:
# [2, 4, 3, 5, 6, 7, 8]

# %%
#Question 2 ) Write a Python program to get the difference between the two lists

# %%
list1=[1,4,5,6,2,7,3]
list2=[1,4,8,9,10,11,3,4,]
final_list1=set(list2)-set(list1)
final_list2=set(list1)-set(list2)
print("Final List 1",final_list1)
print("Final List2",final_list2)
# Out:
# Final List 1 {8, 9, 10, 11}
# Final List2 {2, 5, 6, 7}

# %%
#Question 3) Write a Python program to get the frequency of the elements in a list

# %%
import collections
my_list = [1,1,10,10,0,0,20,20,120,120,50,50,30,30]
print("Original List : ",my_list)
ctr = collections.Counter(my_list)
print("Frequency of the elements in the List : ",ctr)
# Out:
# Original List :  [1, 1, 10, 10, 0, 0, 20, 20, 120, 120, 50, 50, 30, 30]
# Frequency of the elements in the List :  Counter({1: 2, 10: 2, 0: 2, 20: 2, 120: 2, 50: 2, 30: 2})

# %%
#Question 4) Write a Python program to compute the similarity between two lists.
#Sample data:​ ["red", "orange", "green", "blue", "white"], ["black", "yellow", "green", "blue"]
#Expected Output: ​ Color1-Color2: ['white', 'orange', 'red'] Color2-Color1: ['black', 'yellow']

# %%
Color1=["red", "orange", "green", "blue", "white"]
Color2=["black", "yellow", "green", "blue"]
Color1_Color2=set(Color1)-set(Color2)
print("Color1_Color2 :",sorted(Color1_Color2))
Color2_Color1=set(Color2)-set(Color1)
print("Color2_Color1 :",Color2_Color1)
# Out:
# Color1_Color2 : ['orange', 'red', 'white']
# Color2_Color1 : {'black', 'yellow'}

# %%
#Question 5) Write a Python function that takes a list of words and returns the length of the longest one

# %%
def longestLength(a): 
    max1 = len(a[0]) 
    temp = a[0] 
  
    # for loop to traverse the list 
    for i in a: 
        if(len(i) > max1): 
  
            max1 = len(i) 
            temp = i 
  
    print("The word with the longest length is:", temp) 
a = ["one", "two", "third", "four"] 
longestLength(a)
# Out:
# The word with the longest length is: third

# %%
#Question 6) Write a Python program to count the occurrences of each word in a given sentence

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

print( word_count('Write a Python program to count the occurrences of each word in a given sentence.'))
# Out:
# {'Write': 1, 'a': 2, 'Python': 1, 'program': 1, 'to': 1, 'count': 1, 'the': 1, 'occurrences': 1, 'of': 1, 'each': 1, 'word': 1, 'in': 1, 'given': 1, 'sentence.': 1}

# %%
#Question 7) Write a Python program to count and display the vowels of a given text

# %%
def vowel(text):
    vowels = "aeiuoAEIOU"
    print(len([letter for letter in text if letter in vowels]))
    print([letter for letter in text if letter in vowels])
vowel('Python program');
# Out:
# 3
# ['o', 'o', 'a']

# %%
#Question 8) Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in the form (x, x*x)

# %%
n=int(input("Input a number "))
d = dict()

for x in range(1,n+1):
    d[x]=x*x

print(d)
# Out:
# Input a number 20
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361, 20: 400}

# %%
#Question 9 )Write a Python program to combine two dictionary adding values for common keys
# d1 = {'a': 100, 'b': 200, 'c':300}
# d2 = {'a': 300, 'b': 200, 'd':400}
# Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d3 = {}
for i, j in d1.items():
    for x, y in d2.items():
        if i == x:
             d3[i]=(j+y)
print(d3)
# Out:
# {'a': 400, 'b': 400}

# %%
#Question 10) Write a Python program to print all unique values in a dictionary
#Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"},{"V":"S009"},{"VIII":"S007"}]
#Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}

# %%
L = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
u_value = set( val for dic in L for val in dic.values())
print("Unique Values: ",u_value)
# Out:
# Unique Values:  {'S009', 'S005', 'S001', 'S002', 'S007'}
